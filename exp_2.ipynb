# %% [markdown]
# <a href="https://colab.research.google.com/github/poorvautturkar25/Ann/blob/main/23uam135_exp_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Implementation of Gradient Descent for a Simple Linear Regression Problem

import numpy as np
import matplotlib.pyplot as plt

# Sample data: x (input), y (actual output)
x = np.array([50, 60, 70, 80, 90])  # Input features
y = np.array([10, 12, 14, 16, 18]) # Actual outputs (for example, y = 2 * x)

# Initialize weight and bias
w = 0  # initial guess for weight
b = 0  # initial guess for bias

# Hyperparameters
learning_rate = 0.0001
num_iterations = 1000

# Gradient Descent
for i in range(num_iterations):
    y_pred = w * x + b  # Predicted output
    error = y_pred - y  # Error (difference between predicted and true values)

    # Compute gradients (derivatives of cost function)
    dw = (2/len(x)) * np.sum(error * x)  # Gradient with respect to weight
    db = (2/len(x)) * np.sum(error)      # Gradient with respect to bias

    # Update the weights and bias
    w = w - learning_rate * dw
    b = b - learning_rate * db

    # Optionally print progress
    if i % 100 == 0:
        print(f"Iteration {i}: w = {w:.4f}, b = {b:.4f}, MSE = {np.mean(error**2):.4f}")

# Plot the result
plt.scatter(x, y, color='blue', label='True values')
plt.plot(x, w * x + b, color='red', label='Fitted line')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Linear Regression with Gradient Descent')
plt.legend()
plt.show()

print(f"Final weight (w) = {w:.4f}, Final bias (b) = {b:.4f}")
# Out:
# Iteration 0: w = 0.2040, b = 0.0028, MSE = 204.0000
# Iteration 100: w = 0.2000, b = 0.0027, MSE = 0.0000
# Iteration 200: w = 0.2000, b = 0.0027, MSE = 0.0000
# Iteration 300: w = 0.2000, b = 0.0027, MSE = 0.0000
# Iteration 400: w = 0.2000, b = 0.0027, MSE = 0.0000
# Iteration 500: w = 0.2000, b = 0.0027, MSE = 0.0000
# Iteration 600: w = 0.2000, b = 0.0027, MSE = 0.0000
# Iteration 700: w = 0.2000, b = 0.0027, MSE = 0.0000
# Iteration 800: w = 0.2000, b = 0.0027, MSE = 0.0000
# Iteration 900: w = 0.2000, b = 0.0027, MSE = 0.0000
# Final weight (w) = 0.2000, Final bias (b) = 0.0027

# %%
#Student Performance Prediction


import numpy as np
import matplotlib.pyplot as plt

# Sample data
x = np.array([1, 2, 3, 4, 5])
y = np.array([10, 20, 30, 40, 50])

# Initialize weight and bias
w = 0
b = 0

learning_rate = 0.01
num_iterations = 1000

# Gradient Descent
for i in range(num_iterations):
    y_pred = w * x + b
    error = y_pred - y

    # (derivatives of cost function)
    dw = (2/len(x)) * np.sum(error * x)
    db = (2/len(x)) * np.sum(error)

    # Update the weights and bias
    w = w - learning_rate * dw
    b = b - learning_rate * db

    #  print progress
    if i % 100 == 0:
        print(f"Iteration {i}: w = {w:.4f}, b = {b:.4f}, MSE = {np.mean(error**2):.4f}")

# Plot the result
plt.scatter(x, y, color='blue', label='True values')
plt.plot(x, w * x + b, color='red', label='Fitted line')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Linear Regression with Gradient Descent')
plt.legend()
plt.show()

print(f"Final weight (w) = {w:.4f}, Final bias (b) = {b:.4f}")
# Out:
# Iteration 0: w = 2.2000, b = 0.6000, MSE = 1100.0000
# Iteration 100: w = 9.4939, b = 1.8273, MSE = 0.6119
# Iteration 200: w = 9.6393, b = 1.3023, MSE = 0.3108
# Iteration 300: w = 9.7429, b = 0.9282, MSE = 0.1579
# Iteration 400: w = 9.8168, b = 0.6615, MSE = 0.0802
# Iteration 500: w = 9.8694, b = 0.4715, MSE = 0.0407
# Iteration 600: w = 9.9069, b = 0.3360, MSE = 0.0207
# Iteration 700: w = 9.9337, b = 0.2395, MSE = 0.0105
# Iteration 800: w = 9.9527, b = 0.1707, MSE = 0.0053
# Iteration 900: w = 9.9663, b = 0.1217, MSE = 0.0027
# Final weight (w) = 9.9759, Final bias (b) = 0.0870

# %%
import numpy as np
import matplotlib.pyplot as plt

# Step 1: Define the hypothesis function
def hypothesis(theta, X):
    return np.dot(X, theta)

# Step 2: Define the cost function (Mean Squared Error)
def compute_cost(X, y, theta):
    m = len(y)
    predictions = hypothesis(theta, X)
    cost = (1 / (2 * m)) * np.sum((predictions - y) ** 2)
    return cost

# Step 3: Gradient Descent function
def gradient_descent(X, y, theta, learning_rate, iterations):
    m = len(y)
    cost_history = []

    for i in range(iterations):
        # Compute the gradient
        predictions = hypothesis(theta, X)
        error = predictions - y
        gradient = (1 / m) * np.dot(X.T, error)

        # Update the parameters
        theta = theta - learning_rate * gradient
        cost_history.append(compute_cost(X, y, theta))

    return theta, cost_history

# Step 4: Prepare the data
def prepare_data(altitudes, temperatures):
    # Add a column of ones for the intercept term (theta_0)
    X = np.ones((len(altitudes), 2))
    X[:, 1] = altitudes
    y = temperatures
    return X, y

# Step 5: Main function to run the algorithm
def main():
    # Example dataset: altitudes (in meters) and temperatures (in Celsius)
    altitudes = np.array([100, 500, 1000, 1500, 2000, 2500, 3000, 3500, 4000])
    temperatures = np.array([15, 12, 9, 7, 5, 3, 2, 1, 0])

    # Prepare the data
    X, y = prepare_data(altitudes, temperatures)

    # Initial parameters (theta_0 and theta_1)
    theta = np.zeros(2)

    # Hyperparameters
    learning_rate = 0.001
    iterations = 1000

    X[:, 1] = (X[:, 1] - np.mean(X[:, 1])) / np.std(X[:, 1])

    # Run gradient descent to learn theta values
    theta, cost_history = gradient_descent(X, y, theta, learning_rate, iterations)

    # Output the learned parameters
    print(f"Learned parameters: theta_0 = {theta[0]}, theta_1 = {theta[1]}")

    # Plot the cost history
    plt.plot(range(iterations), cost_history)
    plt.xlabel('Iterations')
    plt.ylabel('Cost')
    plt.title('Cost Function Convergence')
    plt.show()

    # Predict temperature at a new altitude (e.g., 1500 meters)
    new_altitude = 1500
    predicted_temp = hypothesis(theta, np.array([1, new_altitude]))
    print(f"Predicted temperature at {new_altitude} meters: {predicted_temp}°C")

# Call the main function to execute the program
if __name__ == "__main__":
    main()
# Out:
# Learned parameters: theta_0 = 3.7938274513742156, theta_1 = -3.0108499980085393
# Predicted temperature at 1500 meters: -4512.481169561434°C

# %%
import numpy as np
import matplotlib.pyplot as plt

# Step 1: Define the hypothesis function
def hypothesis(theta, X):
    return np.dot(X, theta)

# Step 2: Define the cost function (Mean Squared Error)
def compute_cost(X, y, theta):
    m = len(y)
    predictions = hypothesis(theta, X)
    cost = (1 / (2 * m)) * np.sum((predictions - y) ** 2)
    return cost

# Step 3: Gradient Descent function
def gradient_descent(X, y, theta, learning_rate, iterations):
    m = len(y)
    cost_history = []

    for i in range(iterations):
        # Compute the gradient
        predictions = hypothesis(theta, X)
        error = predictions - y
        gradient = (1 / m) * np.dot(X.T, error)

        # Update the parameters
        theta = theta - learning_rate * gradient
        cost_history.append(compute_cost(X, y, theta))

    return theta, cost_history

# Step 4: Prepare the data
def prepare_data(sizes, prices):
    # Add a column of ones for the intercept term (theta_0)
    X = np.ones((len(sizes), 2))
    X[:, 1] = sizes
    y = prices
    return X, y

# Step 5: Main function to run the algorithm
def main():
    # Example dataset: sizes of houses (in square feet) and prices (in dollars)
    sizes = np.array([1400, 1600, 1700, 1875, 1100, 1550, 2350, 2450, 1425, 1700])
    prices = np.array([245000, 312000, 279000, 308000, 199000, 219000, 405000, 324000, 319000, 255000])

    # Prepare the data
    X, y = prepare_data(sizes, prices)

    # Initial parameters (theta_0 and theta_1)
    theta = np.zeros(2)

    # Hyperparameters
    learning_rate = 0.000001
    iterations = 100000

    X[:, 1] = (X[:, 1] - np.mean(X[:, 1])) / np.std(X[:, 1])

    # Run gradient descent to learn theta values
    theta, cost_history = gradient_descent(X, y, theta, learning_rate, iterations)

    # Output the learned parameters
    print(f"Learned parameters: theta_0 = {theta[0]}, theta_1 = {theta[1]}")

    # Plot the cost history
    plt.plot(range(iterations), cost_history)
    plt.xlabel('Iterations')
    plt.ylabel('Cost')
    plt.title('Cost Function Convergence')
    plt.show()

    # Plot the data points and the best-fit line
    plt.scatter(sizes, prices, color='blue', label='Data points')
    plt.plot(sizes, hypothesis(theta, X), color='red', label='Best-fit line')
    plt.xlabel('Size (sq ft)')
    plt.ylabel('Price ($)')
    plt.title('House Price Prediction')
    plt.legend()
    plt.show()

    # Predict price of a new house (e.g., 1600 sq ft)
    new_size = 1600
    predicted_price = hypothesis(theta, np.array([1, new_size]))
    print(f"Predicted price for a house of size {new_size} sq ft: ${predicted_price:.2f}") # Removed [0]

# Call the main function to execute the program
main()
# Out:
# Learned parameters: theta_0 = 27264.09269450183, theta_1 = 4140.934204819359
# Predicted price for a house of size 1600 sq ft: $6652758.82
